# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [X] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Our group was interested in food delivery services, specifically on what factors most influence the user’s satisfaction with their food delivery. Our background research consists of academic articles focusing on previous studies on food delivery. The studies heavily emphasize that expected delivery time and delivery cost are the most significant in negatively influencing customers’ usage and ratings of online food delivery than other expected factors like preparation time, food quality, and cuisine. Additionally, they considered outside factors that can play a factor in the customers’ sensitivity to delivery time such as location, distance, day and time of the week, the customers’ situation and what they were doing. One study highlighted how customers will be less sensitive to later delivery times during peak hours or long distance orders because they will be more accommodating and understanding of those outside factors. Another source discusses how delivery quality matters a lot more in the West Coast and Northeast in particular. From our research, it helps reinforce some of our initial thoughts, particularly about focusing on delivery time and cost along with outside factors like location, distance, day and time of the week. Although we learned that preparation time isn’t as significant, we wanted to test it out if our datasets had this factor since many of us still suspected that food preparation time could be somewhat significant. While some ideas were debunked, specifically the influence of cuisine and food quality. We would consider testing out these factors if our datasets had them, but they aren’t as necessary for us to look or test for.
#
# After narrowing down the variables that would be meaningful to answering our hypothesis, we searched for publicly available datasets that had the necessary columns (i.e. delivery time, customer ratings, day of the week, location, etc). From this, we found the Foodhub, Grubhub, and Doordash datasets. These data sets met the necessary criteria of having at least delivery time, and a metric for measuring customer satisfaction. We managed to have other variables to include in our analysis. For the Foodhub dataset, we manage to have cost of order, day of the week, and food preparation time. While we were able to have location, specifically U.S. states as a variable in Grubhub and Doordash datasets.Though in our efforts to initialize EDAs for possible correlations, our findings were cut short due to a lack of normality and skewness; ultimately limiting the EDA that could be generated. From the EDAs we were able to generate, it showed minimal correlation towards customer rating, resulting in a disheartening conclusion. Further investigations were fruitless due to the previously mentioned limitations.
#
# Our conclusion, while not as exciting as we had initially hoped, shows that there was very little to no correlation between customer satisfaction with food delivery services based on variables such as delivery time, even when compared across different states and cities in the United States. Against our initial hypothesis, and general consensus in the background research, our dataset was unable to generate/find meaningful results. Though our findings are not meant to discourage future research related to the topic, we simply were unable to find any significant result within our observations.

# %% [markdown]
# ## Authors
# Team list and credits:
# - Dat Nguyen: Background research, Data curation, Software, Analysis
# - Carolyn Crane: Background research, Methodology, Writing - review & editing, Visualization, Analysis
# - Kaitlin Lee: Background research, Project administration, Writing - review & editing, Data curation
# - Son Tran: Background research, Conceptualization, Writing - original draft, Visualization, Analysis
# - Lexine Ragua: Project administration, Writing - original draft, Visualization, Analysis

# %% [markdown]
# ## Research Question

# %% [markdown]
# Does delivery time and ratings vary among New York, Illinois, California, Massachusetts, and New Jersey? Which factors (order cost, day of the week, food preparation) significantly influence customer ratings in Foodhub restaurant food delivery orders In New York? Is the effect of delivery time statistically larger than that of food preparation time?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Online food delivery or on-demand food delivery, has become an essential part of consumers’ everyday eating behaviors. The consumers can search for and order food from various restaurants on digital platforms, then couriers deliver the food to the consumers’ doorstep. This allows consumers to reduce time costs for food purchases by eliminating the physical effort of commuting and waiting in line at food establishments. According to a paper “Delivery time reliability in on-demand food delivery: Heterogeneity from attribution effects,” they emphasize the significance of on demand food delivery by stating how “The global ODFD revenue has increased by more than 60 percent, from 254.7 billion US dollars in 2020 to 424.5 billion US dollars in 2024 (Statista, 2024)” (Ma et al.). Since the online food delivery market has been growing significantly, the competition among the delivery platforms has increased as well. Therefore, these platforms have to run their operations more efficiently to remain profitable without hurting customer satisfaction. So these platforms have to understand how consumers think and behave (e.g., how they value delivery time, reliability, delays, and service promises), then use this information to build better decision-making models (e.g., pricing, delivery-time promises, dispatching, and capacity allocation). These platforms no longer simply deliver and provide service, but make effective decisions while being aware of what makes things profitable for them. Additionally, it was observed from this paper that delivery cost and expected delivery time does negatively impact the use of on demand food delivery (ODFD), but the time sensitivity (consumers’ satisfaction in response to delivery time) varies on the consumers. Consumers are generally less sensitive to delivery time during peak hours and of long-distance orders, likely due to them adjusting their service expectations to be more lenient with these circumstances. Early deliveries tend to increase overall usage of ODFD which leads to the idea that people generally like receiving orders earlier than expected, however, there are consumers who dislike early delivery, potentially because they aren’t ready to receive or haven’t arrived at a designated spot for pick up. While late deliveries are widely seen as bad service and decreases ODFD usage. But the late deliveries for long distance orders are less negatively effective because consumers may be more lenient, expecting uncertainty and forgiving of delays. Based on these results, we saw how the cost of food delivery and expected delivery time are the factors that have a lot of impact on the ratings and satisfaction of their experience with online food delivery. But this study emphasizes how the factors that contribute to the customers’ satisfaction to expected delivery time varies based on customers like location, day of the week, time of the week, distance, what they were doing, etc. Therefore, we want to include other factors that can contribute to customer satisfaction with delivery time which will be reflected in their ratings. The factors we considered that are included in our dataset are time of the food order and what day of the week did the customer order as these factors will contribute to the customers’ service expectations which contributes to their ratings of their food delivery orders. From there, our group narrowed down our interests to factors of food delivery like pricing, delivery time, and more that can contribute to customer satisfaction since these reviews on food delivery platforms take many factors into consideration besides food quality. After researching more information about food delivery, we came across a relevant peer-reviewed study that provides theoretical grounding for our research question is “Determinants of Customer Satisfaction via Online Food Delivery Applications”, by Chanin Yoopetch, Pisit Siriphan, and Suthawan Chirapanda (2022). In this study, the authors surveyed 411 users of food delivery apps and used structural equation modeling to analyze how menu variety, food quality, delivery quality, and perceived app value influence customer satisfaction. Their findings showed that perceived value had the strongest effect on restaurant satisfaction, followed by delivery quality, while menu variety and food quality had comparatively weaker direct effects. Overall, the results indicate that delivery performance (including speed, reliability, and overall efficiency) has a stronger and more consistent influence on customer satisfaction than food preparation-related factors alone. These findings suggest that customer may be more sensitive to delivery issues than preparation delays and provide theoretical support for our research question. However, applying these findings requires consideration of alternative perspectives and potential threats to validity. Although this prior research highlights the importance of delivery-related factors, customer satisfaction is multidimensional, meaning factors such as preparation time, cuisine type, order cost, and ordering context (e.g. day of the week) may still influence outcomes. While cuisine-related or menu based characteristics are included in our analysis, they are not a primary focus, as the referenced study found menu-related factors to have comparatively smaller effects on satisfaction outcomes. Instead, our project emphasizes operational variables more directly tied to delivery performance. Looking through online Git projects, we were able to find a few repositories focusing on Food Delivery Times through the usage of prediction models. The repo that we observed the most is delivery_time_prediction, with its creator cleaning a publicly provided dataset on Kaggle, and optimizing it for the prediction model. After exploring a few possible relationships and hypotheses, the variables that ended up contributing the most to food delivery time were: age of the delivery driver, rating of the delivery driver, and the distance between restaurant and delivery location. These findings align with our research question, and poses more inquiry whether or not these results are similar across different scenarios and datasets. Since the Grubhub and Doordash datasets we chose included different states, we consider states as a factor in our project. According to an article “New Survey Examines Regional Restaurant Preferences,” there are some factors that are more preferred in certain regions. For instance, delivery quality matters the most to the people in the West Coast and Northeast. Lastly, the survey concluded that Doordash is the top used food delivery app, followed by Ubereats and Grubhub. Therefore, we will be looking for datasets that have statistics from these platforms since they are likely to have more data we can look at.
# Therefore, for our group project, we aim to narrow our attention to the factors that have been proven to show potential impact on customer satisfaction such as food delivery time. In our project, the datasets will differ in the number of factors we will use since the Grubhub and Doordash datasets have more significant factors than Foodhub. Therefore, we will focus on the influence of the factor delivery time on the review ratings in the Grubhub and Doordash datasets. Then we will apply our findings on delivery time from the other two to Foodhub along with checking other factors such as cost of order, day of the week, food preparation time, and delivery time in Foodhub.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# For the Grubhub and Doordash datasets, we predict that the West Coast and Northeast states will either have quicker delivery times or harsher/lower ratings if the delivery time subverts expectations negatively.
#
# For the Foodhub dataset, we predict that longer waiting times reduce the likelihood that a customer leaves a rating. Both delivery time and food preparation time are expected to have negative effects on rating behavior, with delivery time having a stronger impact.
#
# Customer ratings reflect service quality and satisfaction in food delivery. Using data on delivery times, preparation times, and ratings from Foodhub, this study examines whether longer waits lead to fewer ratings.
#
# For Grubhub and Doordash: Average delivery times significantly differ across states. Ratings are more sensitive to delivery delays in West Coast (California) and Northeast states (New York, Massachusetts, New Jersey). For Foodhub: Longer delivery times significantly decrease customer ratings. Delivery time has a stronger negative effect on ratings than food preparation time. Longer total waiting time reduces the probability that a customer leaves a rating.

# %% [markdown]
# ## Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from scipy import stats
from scipy.stats import spearmanr
from scipy.stats import mannwhitneyu
from eda_functions import state_lmplot, state_scatterplot, mwu_test, compare_lineplot, compare_hexbin_plot

# %% [markdown]
# ### Data overview

# %% [markdown]
# ### Grubhub Dataset
#
# * Dataset #1
#   * Name: "Grubhub Restaurant Data"
#   * Link: https://www.kaggle.com/datasets/polartech/grubhub-restaurant-data?resource=download
#   * Observations: 8088
#   * Variables: 27
#   * Description of the variables:
#     - "searched_state": The state in which the order was placed in
#     - "delivery_time": The time in minutes that the order took to arrive from the restaurant to the ordering address
#     - "review_rating" The rating given by the customer on a 0-5 scale

# %%
grubhub = pd.read_csv('data/00-raw/grubhub.csv')
grubhub.head()
# Out:
#    searched_zipcode  searched_lat  searched_lng  \
# 0             11216     40.678832    -73.950677
# 1             11216     40.678832    -73.950677
# 2             11216     40.678832    -73.950677
# 3             11216     40.678832    -73.950677
# 4             11216     40.678832    -73.950677
#
#                           searched_address searched_state searched_city  \
# 0  300 Madison St, Brooklyn, NY 11216, USA             NY      Brooklyn
# 1  300 Madison St, Brooklyn, NY 11216, USA             NY      Brooklyn
# 2  300 Madison St, Brooklyn, NY 11216, USA             NY      Brooklyn
# 3  300 Madison St, Brooklyn, NY 11216, USA             NY      Brooklyn
# 4  300 Madison St, Brooklyn, NY 11216, USA             NY      Brooklyn
#
#   searched_metro        is_gh   latitude  longitude  ...  delivery_fee  \
# 0             NY  $0 with GH+  40.678829 -73.949867  ...          0.00
# 1             NY  $0 with GH+  40.678715 -73.949875  ...          0.00
# ...

# %% [markdown]
# The dataset above is very robust with 27 columns and over 8000 rows (wow!), but to relate back to our research question, we need to specifically focus on state, delivery time, and review rating among other things. We can drop the other columns that aren't of any interest.

# %%
# Drop irrelevant columns
grubhub_drop_columns = ['searched_zipcode', 'searched_lat', 'searched_lng', 'searched_address', 'searched_metro', 
                        'is_gh', 'latitude', 'longitude', 'cuisines', 'loc_name', 'loc_number', 'url', 'address', 'phone', 
                        'RunDate', 'restaurant_tags', 'delivery_fee_raw', 'delivery_time_raw']

grubhub = grubhub.drop(columns = grubhub_drop_columns)

# Simplify column names to match the other dataset
rename_cols = {'searched_state': 'state',
                'delivery_time': 'delivery_time',
                'review_rating': 'rating'}

grubhub = grubhub.rename(columns = rename_cols)

# Checking for null entries. There are none
print(grubhub.isnull().sum())
print(grubhub.shape)
# Out:
# state            0
# searched_city    0
# distance         0
# delivery_fee     0
# delivery_time    0
# service_fee      0
# review_count     0
# rating           0
# delivery_type    0
# dtype: int64
# (8088, 9)

# %% [markdown]
# Delivery_time can contain a lot of variability! Especially with so many datapoints, so it's best to filter out any outliers. After that, we are done cleaning the Grubhub dataset.

# %%
# Removing any potential outliers for delivery time
Q1 = grubhub['delivery_time'].quantile(0.25)
Q3 = grubhub['delivery_time'].quantile(0.75)
IQR = Q3 - Q1

grubhub = grubhub[(grubhub['delivery_time'] >= Q1 - 1.5*IQR) &
                  (grubhub['delivery_time'] <= Q3 + 1.5*IQR)]

grubhub.head()
# Out:
#   state searched_city  distance  delivery_fee  delivery_time  service_fee  \
# 0    NY      Brooklyn      0.04          0.00           40.0         0.00
# 1    NY      Brooklyn      0.04          0.00           45.0         0.00
# 2    NY      Brooklyn      0.06          1.99           27.5        10.00
# 3    NY      Brooklyn      0.07          1.99           30.0         7.25
# 4    NY      Brooklyn      0.08          1.99           30.0         5.25
#
#    review_count  rating delivery_type
# 0          1691    4.57          SELF
# 1           697    4.77          SELF
# 2            11    3.67       GRUBHUB
# 3           208    4.05       GRUBHUB
# 4             0    0.00       GRUBHUB

# %% [markdown]
# ### Doordash Dataset
# - Dataset #2
#   - Name: "Doordash Restaurant Data"
#   - Link: https://www.kaggle.com/datasets/polartech/doordash-restaurant-data
#   - Observations: 11219
#   - Variables: 26
#   - Description of the variables:<br>
# "searched_state" : The US state the order was placed in<br>
# "delivery_time" : The time, in miutes, that the order took to get from the restaurant to the ordering address<br>
# "review_rating" : The rating given by the customers on a scale of 0-5<br>

# %%
doordash = pd.read_csv('data/00-raw/doordash.csv')
doordash.head()
# Out:
#    searched_zipcode  searched_lat  searched_lng  \
# 0             10003     40.732473    -73.987380
# 1             11219     40.631075    -73.997695
# 2             11216     40.678832    -73.950677
# 3             11219     40.631075    -73.997695
# 4             10003     40.732473    -73.987380
#
#                                     searched_address searched_state  \
# 0  41 Cooper Square, 7 E 7th St, New York, NY 100...             NY
# 1             4701 15th Ave, Brooklyn, NY 11219, USA             NY
# 2            300 Madison St, Brooklyn, NY 11216, USA             NY
# 3             4701 15th Ave, Brooklyn, NY 11219, USA             NY
# 4  41 Cooper Square, 7 E 7th St, New York, NY 100...             NY
#
#   searched_city searched_metro  city_slug   latitude  longitude  ...  \
# 0      New York             NY        NaN  40.675464 -73.980782  ...
# 1      Brooklyn             NY        NaN  40.675464 -73.980782  ...
# ...

# %% [markdown]
# We can see here that, similar to the GrubHub dataset, there are many columns to work with, but very few are relevant to our research. You'll also notice that some columns contain "NaN" entries and only inputs of 0.0 even if they weren't null in the Grubhub dataset. We'll just have to narrow our analysis of Doordash to fit the data we are given.

# %%
# Dropping irrelevant columns
doordash_drop_col = ['searched_zipcode', 'searched_lat', 'searched_lng', 'searched_address', 'searched_metro',
               'city_slug', 'latitude', 'longitude', 'distance', 'loc_name', 'loc_number', 'url', 'address', 'cuisines',
               'delivery_fee_raw',  'delivery_fee', 'delivery_time_raw', 'service_fee_raw', 'service_fee', 'review_count', 'phone', 'RunDate']

doordash = doordash.drop(columns=doordash_drop_col)

# Simplify column names to match the other datasets
doordash = doordash.rename(columns=rename_cols)

# %% [markdown]
# We must also make sure to drop null entries and remove any outliers for the sake of later analysis!

# %%
# Checking for null entries in each column, there are none
doordash.isnull().sum()
# Out:
# state            0
# searched_city    0
# delivery_time    0
# rating           0
# dtype: int64

# %%
# Removing outliers using IQR
d_Q1 = doordash['delivery_time'].quantile(0.25)
d_Q3 = doordash['delivery_time'].quantile(0.75)
d_IQR = d_Q3 - d_Q1

doordash = doordash[(doordash['delivery_time'] >= d_Q1 - 1.5 * d_IQR) & 
    (doordash['delivery_time'] <= d_Q3 + 1.5 * d_IQR)]

# Displaying the cleaned dataframe
doordash.head()
# Out:
#   state searched_city  delivery_time  rating
# 0    NY      New York           29.0     4.8
# 1    NY      Brooklyn           29.0     4.8
# 2    NY      Brooklyn           29.0     4.8
# 3    NY      Brooklyn           28.0     4.6
# 4    NY      New York           28.0     4.6

# %% [markdown]
# ### FoodHub Dataset
#
# * Dataset #3
#     * Name: "NYC Foodhub Data"
#     * Link:
#     * Observations: 1898
#     * Variables: 9
#     * Description of the variables:
#         * "cost_of_the_order": How much the order cost in the form of a float
#         * "day_of_the_week": The day of the week in which the order was placed
#         * "rating": The rating given by the customer on a 0-5 scale
#         * "food_preparation_time": The time in minutes it took for the food to be prepared in the restaurant
#         * "delivery_time": The time in minutes it took for the food to be delivered from the Restaurant to the order address

# %%
foodhub = pd.read_csv('data/00-raw/food_order.csv')
foodhub
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %% [markdown]
# We can keep the columns of interest. We can also see that under the rating column, there exists an entry "Not given". Analysis can't be performed on ratings that don't exist, so we can treat these entries as null and remove them from the dataframe.

# %%
# Dropping columns
drop_cols = ['order_id', 'customer_id', 'restaurant_name', 'cuisine_type']
foodhub = foodhub.drop(columns = drop_cols)

# Dropping "Not given" values
foodhub = foodhub[foodhub['rating'] != 'Not given']
foodhub['rating'] = foodhub['rating'].astype(float)

# %% [markdown]
# After that, we also have to make sure there are no other null entries.

# %%
# Counting up all null entries per column; there are none
print(foodhub.isnull().sum())

# Show how many rows and columns we're left with after cleaning
print(foodhub.shape)
# Out:
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64
# (1162, 5)

# %% [markdown]
# Finally, we can simplify the names of the columns.

# %%
rename_fh = {
    'cost_of_the_order': 'order_cost',
    'day_of_the_week': 'day_type',
    'food_preparation_time': 'prep_time',
    'delivery_time': 'delivery_time',
    'rating': 'rating'
}
foodhub = foodhub.rename(columns = rename_fh)
foodhub.head()
# Out:
#    order_cost day_type  rating  prep_time  delivery_time
# 2       12.23  Weekday     5.0         23             28
# 3       29.20  Weekend     3.0         25             15
# 4       11.59  Weekday     4.0         25             24
# 5       25.22  Weekday     3.0         20             24
# 7        5.97  Weekday     3.0         33             30

# %% [markdown]
# ## Results
#
# ### Grubhub Exploratory Data Analysis
# In this section, we'll explore the Grubhub dataset to visualize the distribution and identify any possible relationships between delivery performance and customer ratings. First, we'll examine the distribution of delivery times to see the general range of minutes it takes for orders to arrive. By doing so, we can also see its shape to inform later statistical modeling decisions.
#
# ### Checking for Normality and Linearity
#
# Before applying statistical models, we need to check whether the variables are approximately normal and whether their relationships appear linear.
#
# To assess this, we first visualize the distribution of delivery times using a histogram and kernel density estimate (KDE). From this, we can see its shape and where a majority of the data is clustered.

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=grubhub,
    x='delivery_time',
    bins=20,            
    kde=True
)

plt.title("Distribution of Delivery Time")# Create bins
grubhub['delivery_bin'] = pd.cut(grubhub['delivery_time'], bins=6)

plt.figure(figsize=(10,5));

# %% [markdown]
# The histogram shows that the distribution of delivery times roughly span between 20 to 70 minutes, with a high concentration of orders being delivered within 25-40 minutes. The shape is slightly right skewed, meaning that while most deliveries occur within a typical window, some can take much longer, causing the right tail of the distribution.
#
# This skewness suggests that delivery performance varies across orders, possibly due to dexternal factors such as distance, restaurant preparation time, or traffic conditions. Non-parametric correlation tests (such as Spearman correlation) may be appropriate when examining relationships between delivery time and customer ratings in later analysis because of the lack of normality.

# %% [markdown]
# ### Relationship Between Delivery Time and Customer Ratings
#
# To explore whether delivery speed influences customer satisfaction, we can visualize the relationship between delivery time and customer ratings on a scatterplot.
#
# Because ratings are discrete values ranging from 1 to 5, many observations overlap on the same horizontal lines. To make the distribution of points clearer, we add a small amount of random noise (jitter) to the rating values, allowing overlapping points to be visible. We then plot delivery time against ratings and color observations by state. Regression lines are included for each state to help visualize potential trends between delivery time and customer ratings across different locations.

# %%
# Add small jitter to rating to better visualize the plotted data
grubhub['rating_jitter'] = grubhub['rating'] + np.random.uniform(-0.1, 0.1, size=len(grubhub))

# To view the full code, refer to eda_functions.py
state_lmplot(grubhub)

# %% [markdown]
# Here, we can see the scatterplot shows a large concentration of ratings between 3 and 5 across all delivery times, suggesting that most orders receive relatively positive customer feedback. The regression lines indicate that the relationship between delivery time and ratings is relatively weak and varies slightly across states. Some states show a mild positive trend while others show a slight negative trend, suggesting that delivery time alone may not strongly determine customer satisfaction.
#
# For further analysis, we can break this scatterplot into subplots separated by state.

# %%
# Full code in eda_functions.py
state_scatterplot(grubhub)

# %% [markdown]
# Now that we can see everything more clearly, some states show a weak positive relationship between delivery time and ratings, while others show a slight negative trend. The positive trend would indicate that longer delivery times yield a higher rating, which intuitively doesn't make much sense, and we also have to recognize that the data forms a "cloud" cluster, making the linear regression line inconclusive in the current state that the data is presented in. This and the weak slopes indicate that delivery time alone may not be a strong predictor of customer satisfaction.
#
# This preliminary visualization suggests that additional factors such as restaurant quality, order price, or service fees, may play a more significant role in determining customer ratings. To investigate this further, we next examine correlation statistics and regression models to quantify these relationships.

# %% [markdown]
# ### Correlation Matrix of Key Variables
#
# To better understand the relationships between the main variables in the dataset, we compute a correlation matrix for ratings, distance, delivery fees, delivery time, service fees, and review counts. The heatmap visualizes the strength and direction of linear relationships between these variables.

# %%
sns.heatmap(
    grubhub[['rating','distance','delivery_fee','delivery_time','service_fee','review_count']].corr().round(2),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# In the matrix above, the correlations between customer ratings and the other variables appear relatively weak. Delivery time shows almost no correlation with ratings (≈ 0.02), suggesting that longer delivery times do not strongly predict lower customer satisfaction in this dataset.
#
# Service fees show a modest negative correlation with ratings (≈ -0.27), which may suggest that higher service fees are associated with slightly lower ratings. Meanwhile, review count has a small positive relationship with ratings (≈ 0.25), indicating that restaurants with more reviews may tend to have slightly higher ratings. We also see that distance and delivery fees have a moderate positive correlation (≈ 0.34), which is intuitive because longer delivery distances often result in higher delivery charges.
#
# Overall, the heatmap suggests that no single variable has a strong linear relationship with ratings, motivating the use of multivariable regression models to examine whether combinations of factors better explain variation in customer ratings.

# %% [markdown]
# ### Distribution of Customer Ratings (Ratings > 3)
# When plotting the scatterplots, there appeared to be quite a number of reviews with a rating of 0 evenly spread out regardless of delivery time. This lack of a correlation does not aid our analysis, so we can specifically examine more positive reviews and reevaluate any correlations that may exist.

# %%
# Remove any rating less than 3 ratings
grubhub_test_2 = grubhub[grubhub['rating'] > 3].copy()

# Generating a histogram plot 
sns.histplot(grubhub_test_2['rating'], bins=10, kde=True)
plt.title("Distribution of Ratings")
plt.show()

# %% [markdown]
# The distribution of ratings is concentrated between approximately 3.3 and 4.7, with most observations clustering around the 3.5–4.5 range. This tells us that a majority of the orders in the Grubhub dataset received moderately positive customer reviews. The also tells us that the distribution of this filtered dataset appears more normal than the unfiltered one (which would have another peak at 0, making it bimodal and non-normal). We could attempt to run parametric inferential analysis later on because of this, but we may encounter some issues.
#
# Overall, the limited spread of ratings suggests that customer feedback tends to be consistently positive, which may make it more difficult for individual factors like delivery time to strongly influence ratings.

# %% [markdown]
# ### Delivery Time vs Rating Across States (Ratings > 3)
#
# To further examine the relationship between delivery time and customer satisfaction, we filtered the dataset to include only ratings greater than 3. We can rerun the state scatterplots from one of the earlier visualizations and see if there's any improvement in correlation.

# %%
# Add jitter to rating
grubhub_test_2['rating_jitter'] = grubhub_test_2['rating'] + np.random.uniform(-0.1, 0.1, size=len(grubhub_test_2))

state_scatterplot(grubhub_test_2)

# %% [markdown]
# Across all states, ratings remain clustered between approximately 3 and 5, indicating that most orders receive moderately high customer feedback.
#
# The regression lines suggest only weak relationships between delivery time and ratings. In most states, the slopes appear slightly positive, meaning ratings may increase slightly with longer delivery times, though the effect is small and it inuitively doesn't hold up. New Jersey shows a nearly flat or slightly negative trend.
#
# Overall, delivery time does not appear to be the only influence over customer ratings, suggesting that other factors such as restaurant quality, pricing, or service characteristics may play a more significant role in determining customer satisfaction. We can test this by rerunning the correlation matrix with our filtered dataset.

# %% [markdown]
# ### Correlation Analysis of Delivery Features (Ratings > 3)
#
# To better understand relationships between delivery characteristics and customer satisfaction, we compute a correlation matrix using observations where ratings are greater than 3. This filtering focuses the analysis on moderately to highly rated orders and reduces noise from extremely low ratings.

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    grubhub_test_2[['rating','distance','delivery_fee','delivery_time','service_fee','review_count']].corr(),
    annot=True,
    cmap='coolwarm'
)
plt.title("Correlation Matrix (Ratings > 3)")
plt.show()

# %% [markdown]
# In the heatmap above, the correlation matrix indicates that most variables still have weak relationships with customer ratings.
#
# Similar to our findings from the unfiltered Grubhub data, ratings show a small positive correlation with review count (≈ 0.29) and delivery time shows a very weak positive relationship with ratings (≈ 0.13), indicating that longer delivery times do not strongly reduce customer satisfaction in this dataset. Service fees display a moderate negative correlation with ratings (≈ -0.23), suggesting that higher service fees are associated with slightly lower customer satisfaction. We also see that distance and fees have a moderate positive correlation (≈ 0.33) like it did in the previous correlation matrix.
#
# Overall, the correlations are relatively small, indicating that no single delivery-related variable strongly explains customer ratings. This motivates the use of multivariable regression models to examine how these factors jointly influence customer satisfaction.

# %% [markdown]
# ### Multivariable OLS Regression: Predicting Customer Ratings
#
# To examine how multiple delivery-related factors jointly relate to customer ratings, we can attempt to use a multivariable Ordinary Least Squares (OLS) regression model. The model predicts ratings using delivery time, delivery fees, service fees, delivery distance, and state-level fixed effects. While our data may not be parametric, we can examine the results and see how it runs.

# %%
formula = 'rating ~ delivery_time + delivery_fee + service_fee + distance + C(state)'

model = ols(formula, data=grubhub_test_2).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 rating   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     67.02
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):          2.79e-106
# Time:                        22:48:33   Log-Likelihood:                -4048.0
# No. Observations:                6659   AIC:                             8114.
# Df Residuals:                    6650   BIC:                             8175.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          4.1468      0.029    143.590      0.000       4.090       4.203
# ...

# %% [markdown]
# The regression results indicate that several delivery-related variables have statistically significant relationships with customer ratings, although the overall explanatory power of the model is relatively low (R² ≈ 0.075).
#
# Delivery time shows a small positive coefficient, suggesting that longer delivery times are weakly associated with slightly higher ratings when controlling for other factors. However, the magnitude of this relationship is very small.
#
# Both delivery fees and service fees show negative coefficients, indicating that higher fees are associated with slightly lower customer ratings. Delivery distance also has a small negative relationship with ratings.
#
# State-level effects are statistically significant, suggesting that average ratings differ across states even after controlling for delivery characteristics.
#
# Overall, while several variables are statistically significant, the low R² indicates that these delivery-related factors explain only a small portion of the variation in customer ratings. This means that other factors that were not present in the Grubhub dataset like customer expectations may play a larger role in evaluating food delivery satisfaction.

# %% [markdown]
# ### Comparing Ratings Across States: Mann–Whitney U Test
#
# From the OLS regression, we learn that there might be a significant difference in ratings between different US states, so we can examine this by conducting a Mann–Whitney U test comparing ratings in New York and New Jersey. We pivot to this non-parametric test as it does not assume normality, which may have been a potential limitation for our data to begin with.
#
# The test evaluates whether the distributions of ratings between the two states are statistically different.

# %%
# Creating subset dataframes
NY_ratings = grubhub[grubhub['state'] == 'NY']['rating']
NJ_ratings = grubhub[grubhub['state'] == 'NJ']['rating']

# Full code can be found in eda_functions
mwu_test(NY_ratings, NJ_ratings, "NY", "NJ", "ratings")
# Out:
# Mann-Whitney U statistic: 963889.00
# P-value: 7.7869e-04
# Result: Significant difference between NY and NJ ratings
# Effect size r: 0.058

# %% [markdown]
# #### Interpretation
#
# The Mann–Whitney U test results indicate a statistically significant difference between ratings in New York and New Jersey (p < 0.05). This suggests that the distribution of customer ratings differs between the two states.
#
# However, the calculated effect size (r ≈ 0.058) is very small. This indicates that while the difference is statistically significant, the magnitude of the difference between the two states is minimal.
#
# In practice, this suggests that although ratings may differ slightly between New York and New Jersey, the difference is unlikely to be practically meaningful.

# %% [markdown]
# ### DoorDash Exploratory Data Analysis
#
# To explore relationships between delivery time and customer ratings across states, we begin with a pairplot visualization. This plot allows us to observe both the distribution of each variable and their pairwise relationships while distinguishing observations by state.

# %%
sns.pairplot(doordash, hue='state');

# %% [markdown]
# We can see from the pairplot that the relationship between delivery time and rating is similar to that of the Grubhub data, where a majority of the reviews form a "cloud" at the top half of the graph, indicating an unclear correlation. Ratings also seem to be a bimodal distribution with heavy left skewness.
#
# The pairplot shows that delivery times generally range between approximately 15 and 60 minutes across all states. Customer ratings are heavily concentrated between 4 and 5, indicating generally high satisfaction across the platform. The distribution of ratings appears slightly bimodal with some low outlier ratings near 0 or 1, which may represent canceled orders or extreme customer experiences.
#
# To see the differences in the state data more clearly, we can run a similar scatterplot from the Grubhub EDA.

# %% [markdown]
# ### Relationship Between Delivery Time and Customer Ratings

# %%
state_scatterplot(doordash)

# %% [markdown]
# Above, the regression lines across states show only very slight positive or negative slopes, suggesting that delivery time has little to no meaningful effect on ratings. Although small differences appear between states, these trends are weak and likely reflect random variation rather than a strong relationship.
#
# Overall, the results suggest that delivery time does not significantly influence customer ratings in the DoorDash dataset, consistent with patterns observed in the Grubhub analysis. We can filter the data to only include positive reviews (> 3) to remove the 0 ratings that weigh down on the slope of the regression line.

# %% [markdown]
# ### Delivery Time vs Rating Across States (Ratings > 3)

# %%
doordash_subset = doordash[doordash['rating'] > 3].copy()
state_scatterplot(doordash_subset)

# %% [markdown]
# The regression lines across states appear nearly horizontal, suggesting little to no linear relationship between delivery time and customer ratings. New York seems to be the only one with a negative correlation, meaning that there is a minor tendency for review ratings to dip with longer delivery times, but the dip in rating does not appear to be significant. Ratings remain highly concentrated between 4 and 5 regardless of delivery duration.
#
# To more closely analyze the correlation, we can compute Doordash's Spearman Rank correlation between delivery time and rating.
#
# ### Spearman Correlation

# %%
doordash_corr, doordash_p = spearmanr(doordash['delivery_time'], doordash['rating'])
print(f"Delivery Time vs Rating: correlation = {doordash_corr:.3f}, p-value = {doordash_p:.3f}")
# Out:
# Delivery Time vs Rating: correlation = -0.025, p-value = 0.010

# %% [markdown]
# #### Interpretation
#
# The result shows a very small negative correlation (ρ = −0.025). Although the p-value is statistically significant due to the large sample size, the effect size is negligible. This indicates that delivery time has little to no practical influence on customer ratings. The correlation coefficient here is near 0, indicating that there is a very weak association between delivery time and rating in the Doordash data. This is similar to the conclusions drawn from our Grubhub EDA.

# %% [markdown]
# ### FoodHub EDA
#
# To better understand how operational factors may influence customer ratings, we analyze the FoodHub dataset as a **comparison case**. This dataset contains information on order cost, preparation time, delivery time, and customer ratings for food delivery orders.
#
# We begin with descriptive statistics and visualizations to understand the distribution of the variables. In particular, we examine how ratings are distributed and whether operational variables such as delivery time, preparation time, and order cost appear to relate to customer satisfaction.
#
# We can start our analysis by looking at Foodhub's descriptive statistics and visualizing the distribution of data's ratings.

# %%
foodhub.describe()
# Out:
#         order_cost       rating    prep_time  delivery_time
# count  1162.000000  1162.000000  1162.000000    1162.000000
# mean     16.760766     4.344234    27.381239      24.154045
# std       7.572578     0.741478     4.677922       4.930999
# min       4.470000     3.000000    20.000000      15.000000
# 25%      12.130000     4.000000    23.000000      20.000000
# 50%      14.600000     5.000000    27.000000      25.000000
# 75%      22.750000     5.000000    32.000000      28.000000
# max      35.410000     5.000000    35.000000      33.000000

# %% [markdown]
# Above, we see that the dataset contains 1,162 observations of food delivery orders. On average, the order cost is about $16.76, the average preparation time is about 27 minutes, and the average delivery time is about 24 minutes. The average customer rating is 4.34, indicating that most orders receive relatively high ratings.
#
# Looking at the quartiles, the median rating is 5, and both the 75th percentile and maximum rating are also 5. This suggests that ratings are heavily concentrated at the upper end of the scale, meaning customers tend to give high ratings.
#
# To better visualize this, we plotted a histogram of the rating distribution.
#
# ### Plotting Ratings for FoodHub

# %%
sns.histplot(foodhub['rating'], bins=5)
plt.title("Distribution of Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Here, we can see three different peaks due to the discrete nature of the rating data. Unlike Grubhub and Doordash with the possibility of giving a decimal rating, Foodhub operates on integer ratings. There's also skewness in this distribution, showing us that most of the reviews are 5s. The fact that this data is truly ordinal and non-normal, we will later rely on statistical tests that are more appropriate for this type of data when evaluating potential relationships.
#
# Next, we move onto check if there are any differences between food delivery orders made on the weekdays vs. weekends.

# %%
sns.boxplot(x='day_type', y='rating', data=foodhub)

plt.title("Ratings by Day Type")
plt.xlabel("Day Type")
plt.ylabel("Rating")

plt.show()

# %% [markdown]
# There does not appear to be any major distinction between the day types, so we can move on plot a correlation matrix to analyze the correlation between the numerical variables.
#
# ### Correlation Analysis of Operational Variables
#
# To examine potential relationships between operational factors and customer ratings, we compute a correlation matrix for ratings, delivery time, preparation time, and order cost. The heatmap below visualizes the pairwise correlations between these variables.

# %%
sns.heatmap(foodhub[['rating','delivery_time','prep_time','order_cost']].corr(),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# The correlation matrix shows that customer ratings have almost no linear relationship with delivery time, preparation time, or order cost. All correlation values are extremely close to zero (approximately −0.01 to 0.03), indicating that changes in these variables do not strongly correspond with changes in ratings.
#
# This suggests that operational factors such as delivery time, preparation time, and order cost may not be strong predictors of customer satisfaction in the FoodHub dataset.
#
# To further explore potential relationships between delivery time and ratings, we next visualize the data using scatterplots with regression lines.
#
# ### Delivery Time vs Ratings

# %%
sns.regplot(
    x='delivery_time',
    y='rating',
    data=foodhub,
    x_jitter=0.3,
    y_jitter=0.05
)

plt.title("Delivery Time vs Customer Rating")
plt.xlabel("Delivery Time (minutes)")
plt.ylabel("Customer Rating")

plt.show()

# %% [markdown]
# The scatterplot shows that customer ratings remain relatively stable across the observed range of delivery times. Ratings are concentrated between 3 and 5 regardless of delivery duration, and the regression line appears nearly flat, indicating that delivery time has little to no linear relationship with customer ratings.
#
# This finding is consistent with the earlier correlation analysis, where correlations between ratings and operational variables were extremely close to zero.
#
# ### Spearman Rank Correlation
#
# With this lack of linearity and the skewness, we've learned that an OLS regression model won't be applicable in this case. Instead, we'll default to calculating the Spearman Rank correlation for preparation time, order cost, and delivery time.

# %%
d_corr, d_p = spearmanr(foodhub['delivery_time'], foodhub['rating'])
p_corr, p_p = spearmanr(foodhub['prep_time'], foodhub['rating'])
c_corr, c_p = spearmanr(foodhub['order_cost'], foodhub['rating'])

print("Spearman Correlation Results")
print("----------------------------")
print(f"Delivery Time vs Rating: correlation = {d_corr:.3f}, p-value = {d_p:.3f}")
print(f"Prep Time vs Rating:     correlation = {p_corr:.3f}, p-value = {p_p:.3f}")
print(f"Order Cost vs Rating:    correlation = {c_corr:.3f}, p-value = {c_p:.3f}")
# Out:
# Spearman Correlation Results
# ----------------------------
# Delivery Time vs Rating: correlation = 0.001, p-value = 0.981
# Prep Time vs Rating:     correlation = -0.007, p-value = 0.816
# Order Cost vs Rating:    correlation = 0.038, p-value = 0.191

# %% [markdown]
# All Spearman correlation coefficients are extremely close to zero, and none are statistically significant (p > 0.05). This indicates that there is no meaningful monotonic relationship between these factors and customer ratings in the FoodHub dataset.

# %% [markdown]
# ### Cross-Platform Correlation Analysis of Delivery Time and Ratings
#
# To determine whether delivery time meaningfully influences customer ratings across food delivery platforms, we compare the correlation results from the FoodHub, Grubhub, and DoorDash datasets. Across all three datasets, the relationships between delivery time and customer ratings appear extremely weak.
#
# The correlation heatmaps show that ratings have almost no linear relationship with delivery time, preparation time, or order cost. All Pearson correlation values are very close to zero, suggesting that variations in these operational variables do not correspond strongly with changes in customer ratings.
#
# As for the Spearman rank correlation results, the correlation coefficients across all datasets were very close to zero, indicating only negligible associations. Although some tests produce statistically significant p-values due to the large sample sizes, the effect sizes remain extremely small.
#
# Overall, the consistency of these findings across multiple datasets suggests that delivery time alone is not a strong predictor of customer ratings. Other factors may play a more substantial role in determining how customers evaluate their orders.

# %%
# Full code in eda_functions.py
compare_lineplot(foodhub, grubhub, doordash)

# %% [markdown]
# The average ratings across delivery time bins appear relatively stable for all three platforms. None of the lines show a consistent upward or downward trend as delivery time increases. While there are small fluctuations between bins, these variations do not suggest a strong or systematic relationship between delivery time and customer ratings.
#
# Overall, the patterns across DoorDash, FoodHub, and Grubhub are fairly similar, indicating that longer delivery times do not consistently correspond to lower customer ratings. This visual trend aligns with the earlier correlation analyses, which also suggested that delivery time has little influence on customer ratings.
#
# There is however, an observable difference in average ratings between Doordash and Grubhub. We can run Mann-Whitney U against their ratings and delivery times to check for any significant differences.

# %%
# Creating subsets for ratings only
doordash_ratings = doordash["rating"]
grubhub_ratings = grubhub["rating"]
foodhub_ratings = foodhub["rating"]

mwu_test(doordash_ratings, grubhub_ratings, "Doordash", "Grubhub", "ratings")
# Out:
# Mann-Whitney U statistic: 63282062.00
# P-value: 0.0000e+00
# Result: Significant difference between Doordash and Grubhub ratings
# Effect size r: 0.398

# %%
# Creating subsets for delivery time only
doordash_dt = doordash["delivery_time"]
grubhub_dt = grubhub["delivery_time"]
foodhub_dt = foodhub["delivery_time"]

mwu_test(doordash_dt, grubhub_dt, "Doordash", "Grubhub", "delivery times")
# Out:
# Mann-Whitney U statistic: 31638917.00
# P-value: 7.3927e-216
# Result: Significant difference between Doordash and Grubhub delivery times
# Effect size r: -0.228

# %% [markdown]
# From this, we can see that Doordash has moderately higher ratings and shorter delivery times overall in comparison to Grubhub. This indicates a possibility that Doordash's customer satisfaction may be higher than Grubhub's because of their speed, but this is not fully supported by our data since our earlier Spearman correlation showed a low size effect.
#
# To close up our cross-platform analysis, we will do one last comparison of rating distributions using a density plot.

# %%
# Full code in eda_functions.py
compare_hexbin_plot(foodhub, grubhub, doordash)

# %% [markdown]
# The hexbin plots illustrate the density of customer ratings across delivery times for each platform. Across FoodHub, Grubhub, and DoorDash, the highest concentration of observations appears in the rating range between 4 and 5, regardless of delivery time.
#
# While delivery times vary across platforms, the density patterns remain relatively consistent. Higher ratings are common across both shorter and longer delivery times, and there is no strong concentration of lower ratings at longer delivery durations.
#
# Overall, the visual patterns **once again** suggest that delivery time does not strongly influence customer ratings like we initially expected. This observation is consistent with the earlier correlation and statistical analyses, which also indicated very weak relationships between delivery time and ratings across platforms.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
# - [ ] **A.1 Informed consent:** If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent? <br>
# *The food delivery platforms tend to ask the consumers for consent with privacy policies and app permissions for certain personal information like location, payment details, name, and more, while using the app. Therefore, these consumers know that these apps have access to and store their information they allow when using the app. We do acknowledge that people may not be aware if their information is being used for data for project purposes or are open to the public. But we are considering the possibility that these platforms have included the chances of their data being used for research purposes in their privacy policies, however, we don’t know for sure.* <br>
# - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those? <br>
# *Observing the three datasets, we found no real bias or inconsistencies during data collection. The information collected seems to be unbiased, relaying the raw information if it is provided to the company. Any possible bias would be from the user's location, specifically if there are more people using the delivery apps in New York compared to Massachusetts in the Grubhub and Doordash dataset.* <br>
# - [ ] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis? <br>
# *Our dataset has minimized exposure of personal information by keeping the customer’s identity anonymous. While it does have information based on the ordering location, there is no other identifying information that can be linked to the user’s. It is standard practice for food delivery apps like Grubhub and Doordash to require location information to complete the delivery process, therefore, it does not inherently infringe on the privacy of any user’s information. Additional information like phone numbers are a requirement through Grubhub to prevent fraud, thus making it a relevant and important information.* <br>
# - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)? <br>
# *This bias mitigation is not an issue to be considered since the collected data in the dataset does not inherently treat or label the data/columns in specific personalized ways that would result in bias outcomes.* <br>
# ### B. Data Storage
# - [ ] **B.1 Data security:** Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)? <br>
# *Since the data is collected from Foodhub, Grubhub and Doordash, the companies would already have an established protection plan to secure the user data.*
# - [ ] **B.2 Right to be forgotten:** Do we have a mechanism through which an individual can request their personal information be removed? <br>
# *Grubhub, Doordash, and Foodhub are able to limit the collection, sales, or sharing of any personal data upon the individual’s request.*
# - [ ] **B.3 Data retention plan:** Is there a schedule or plan to delete the data after it is no longer needed? <br>
# *The dataset is publicly available from Foodhub, Grubhub, and Doordash, therefore we do not have ownership of the data and how it is used.*
# ### C. Analysis
# - [ ] **C.1 Missing perspectives:** Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)? <br>
# *Yes, we did consider addressing a potential blindspot with the dataset potentially focusing only on highlighting populated areas of the United States. We would need to consider if this would be a factor on how delivery time is judged and access through customer satisfaction.*
# - [ ] **C.2 Dataset bias:** Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)? <br>
# *We have examined the data and taken steps to omit any data sources that seem incomplete or will create bias for our analysis. Though most of the data is clear and filtered, with a few personalized rows being omitted due to user’s privacy.*
# - [ ] **C.3 Honest representation:** Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data? <br>
# *We will do our best to utilize appropriate visualizations for the variables and the data it represents to prevent bias or non-correlated findings. We will ensure that our visualizations, summary statistics, and reports are honest to the represented data.* <br>
# - [ ] **C.4 Privacy in analysis:** Have we ensured that data with PII are not used or displayed unless necessary for the analysis? <br>
# *Our dataset only contains the most important and relevant data required by Grubhub, Doordash, and Foodhub, with the customer’s consent and approval. Additionally, we will filter and retain only the most relevant and significant variables for our research questions and hypotheses testing.*
# - [ ] **C.5 Auditability:** Is the process of generating the analysis well documented and reproducible if we discover issues in the future? <br>
# *Yes, the analysis will be well documented to ensure that it is reproducible. All of our codes and visualizations will be documented and publicized to make sure that anyone can replicate our results and findings.*
#
# ### D. Modeling
# - [ ] **D.1 Proxy discrimination:** Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
# - [ ] **D.2 Fairness across groups:** Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# - [ ] **D.3 Metric selection:** Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# *Although our project does not involve building predictive models, we considered issues related to fairness, proxies, and interpretability in our analysis. We ensured that our variables do not unfairly discriminate between groups, that our results can be clearly explained, and that limitations, biases, and assumptions are communicated in a way that any potential stakeholders and readers can understand. By addressing these points, we aimed to make our findings transparent, equitable, and actionable without relying on machine learning models.*
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# *Since our group does not plan to develop any models, we do not have any plan to release a model for public use. Therefore, we would not need to consider the consequences of deployment.*

# %% [markdown]
# ## Discusison and Conclusion
#
# ### Limitation
#
# Unfortunately, we faced several limitations when examining correlational relationships among the datasets. The Foodhub dataset had a restricted ratings scale (3, 4, 5, or NA). This limited our ability to observe the relationship between customer satisfaction and how other variables may have influenced it. It also limited our ability to generate certain EDAs due to the restrictiveness nature of the rating columns. The Grubhub and Doordash datasets, while having the necessary variables of customer rating and delivery time, they both lacked many critical variables like preparation time and day of the week, leaving us with a limited range of possible EDAs and correlational relationships. Moreover, the methods of collecting the data were unclear, with variables like distance being labeled in an unknown measurement. Statistical analyses were also unable to be generated due to the skewness of the Grubhub and Doordash dataset, preventing log transformation, which violated the normality assumptions required for reliable OLS regression and ANOVA analysis. To maintain dataset integrity, we ultimately chose to work with the most widely available variables and columns, leading to more limited findings. These limitations weakened our ability to detect more, possibly stronger, relationships within the datasets. With a more informative dataset containing all the necessary variables, it might’ve been possible that a stronger relationship between customer’s rating and delivery time would emerge.
#
# ### EDAs Summarization
#
# From the Foodhub EDA’s, the variables showed almost no correlation with customer ratings. Correlation values between ratings and delivery time, preparation time, and order cost were all extremely close to zero (~0.01 - 0.03), indicating that changes in these variables did not meaningfully correspond with changes in customer satisfaction. Ratings were also highly concentrated at the upper end of the scale, with most values ranging from 4 - 5, which did produce a skewed distribution with limited variability. Additional analyses, including scatterplots and an OLS regression model, reinforced these findings. From the Grubhub EDAs, delivery time showed very weak correlations with customer ratings (|0.06| to |0.27|) that sometimes alternated in signs across different states. Most stronger correlations from the correlation matrix were only between related variables, such as delivery fee and distance. The rating distribution was highly skewed, with many extreme ratings and very few in the middle, which made further analysis challenging. As a result, reliable OLS or ANOVA analyses could not be performed, even after attempting to filter ratings for normality. From the Doordash EDAs, delivery time also show a very weak correlations with customer rating (|0.01|to |0.08|), alternating in signs across different states. Once again, the strongest correlation from the correlation matrix were between related variables like delivery time and order costs. With the rating distribution also highly skewed, we tested a Spearman Correlation, resulting in a correlation of -0.025 and p-value of 0.01.
#
# ### What have we learned
#
# Unlike our background research that emphasizes delivery quality such as time and cost being significant in customer ratings, delivery time showed little to no correlation with customer ratings across all three datasets, with its correlation being so low that it could’ve been by chance. Therefore, our results suggest that delivery time is not a strong or consistent predictor of customers’ ratings. Since customers have their own standards and priorities, satisfaction may depend more on other factors, such as food quality, pricing, or overall service experience, rather than delivery time alone. Among our findings, the distribution about the customer’s rating was very skewed, favoring either very negative or positive reviews. This aligns with our initial expectations that customer ratings may be biased because not every customer leaves a review after placing an order. This is due to customer ratings being complex to work with because of ceiling and floor effects. People tend to give ratings if something significantly bad or good happened to them. Therefore, most customers would leave a super high or low review based on memorable services, whether it is excellent or terrible. If nothing in particular happened to their order and customers received their food, they feel more likely to not leave a review or rating since there is nothing major to rate on. Therefore, the datasets we have found will have many ratings on extreme sides with no to little ratings in the middle. In retrospect, these results of our findings did help to illustrate an important aspect of scientific research; a lack of result is also a type of result. While we were unable to identify any correlation relationship between ratings and other variables, it still allowed us to answer our research question and hypothesis. There might have been other factors affecting customer satisfaction such like their mood or delivery service that was beyond our capabilities. Therefore, it is still worthwhile to research these topics to observe how companies like Grubhub and Doordash operate, and how this affects us as consumers. This is especially significant for online food delivery platforms such as Grubhub and Doordash to pay attention to how customers respond to these factors. These platforms will have a better understanding of clients and their preferences, using this information to make effective decisions that will benefit customers and make profit for themselves.
#
# ### Moving Onwards
#
# If the project were to be continued, future works would be focused on obtaining more completed and refined datasets that include additional variables such as preparation time, order cost and delivery fee, distance, and restaurant rating. These factors may have a stronger impact on customer satisfaction than delivery time alone. Additionally, using datasets with a wider rating scale and more normal distribution would allow for a more comprehensive statistical analysis. By incorporating these additional variables and improved datasets, future research could provide a more complete understanding of what truly drives customer satisfaction in food delivery services.
